# %%
import requests
import pandas as pd


def run_query(query):  # A simple function to use requests.post to make the API call.
    headers = {'X-API-KEY': 'BQYYquuv9iE4tUkIy1vo381YcGGrK5y2'}
    request = requests.post('https://graphql.bitquery.io/',
                            json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed and return code is {}.      {}'.format(request.status_code,
                                                                             query))


part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-11-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        nov = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        nov = nov.append(temp)
        #print(nov)


nov
# Out:
#       protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0   Uniswap v2   670.279831  2.884778e+06    0.000232       0.000234
# 1   Uniswap v2   479.830148  2.068775e+06    0.000232       0.000233
# 2   Uniswap v2  1449.868114  6.157868e+06    0.000235       0.000238
# 3   Uniswap v2   590.761095  2.490386e+06    0.000237       0.000239
# 4   Uniswap v2  1313.282787  5.511679e+06    0.000238       0.000241
# ..         ...          ...           ...         ...            ...
# 19  Uniswap v2   913.978821  4.225716e+06    0.000216       0.000284
# 20  Uniswap v2   711.936211  3.310087e+06    0.000215       0.000216
# 21  Uniswap v2   875.399528  4.057450e+06    0.000216       0.000218
# 22  Uniswap v2   528.185865  2.455842e+06    0.000215       0.000217
# 23  Uniswap v2   397.693858  1.846399e+06    0.000215       0.000216
#
#     minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 0        0.000231  38413214.0  29159.327015  6.262190  2021-11-01 00:00:00
# 1        0.000230  36874734.0  24231.319601  4.934866  2021-11-01 01:00:00
# 2        0.000232  44830045.0  32818.816360  6.840088  2021-11-01 02:00:00
# 3        0.000235  37974631.0  24746.573939  5.127006  2021-11-01 03:00:00
# 4        0.000234  40793994.0  27035.641201  5.379376  2021-11-01 04:00:00
# ..            ...         ...           ...       ...                  ...
# 19       0.000213  34372038.0  28362.580451  6.104142  2021-11-30 19:00:00
# 20       0.000209  38647322.0  33511.249945  6.678433  2021-11-30 20:00:00
# 21       0.000214  29806603.0  26684.297126  4.977179  2021-11-30 21:00:00
# 22       0.000214  29752013.0  22942.129136  4.736033  2021-11-30 22:00:00
# 23       0.000214  31191445.0  20836.703928  4.103106  2021-11-30 23:00:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 19                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 20                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 23                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 19                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 20                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 21                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 22                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 23                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [720 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-10-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        octo = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        octo = octo.append(temp)
        #print(nov)


octo
# Out:
#       protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0   Uniswap v2  1099.658313  3.315697e+06    0.000332       0.000335
# 1   Uniswap v2   634.578549  1.913137e+06    0.000332       0.000334
# 2   Uniswap v2   891.988400  2.679785e+06    0.000333       0.000337
# 3   Uniswap v2  1057.840402  3.166389e+06    0.000334       0.000336
# 4   Uniswap v2   385.614416  1.157307e+06    0.000333       0.000335
# ..         ...          ...           ...         ...            ...
# 19  Uniswap v2   658.826673  2.802978e+06    0.000235       0.000236
# 20  Uniswap v2   821.433701  3.496513e+06    0.000235       0.000237
# 21  Uniswap v2   951.983926  4.086841e+06    0.000233       0.000235
# 22  Uniswap v2   560.436128  2.435660e+06    0.000230       0.000233
# 23  Uniswap v2   703.537821  3.020869e+06    0.000233       0.000234
#
#     minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 
00:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 19                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 20                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 23                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 19                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 20                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 21                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 22                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 23                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [744 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-06-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jun = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jun = jun.append(temp)
        #print(nov)


jun
# Out:
#       protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0   Uniswap v2  2806.124708  7.645911e+06    0.000367       0.000386
# 1   Uniswap v2  2936.189011  7.895891e+06    0.000372       0.000376
# 2   Uniswap v2  2371.584303  6.261575e+06    0.000379       0.000382
# 3   Uniswap v2  3450.218544  9.130871e+06    0.000378       0.000382
# 4   Uniswap v2  1631.905879  4.304286e+06    0.000379       0.000382
# ..         ...          ...           ...         ...            ...
# 19  Uniswap v2  2169.298980  4.822630e+06    0.000450       0.000456
# 20  Uniswap v2  3189.995995  7.196321e+06    0.000443       0.000455
# 21  Uniswap v2  2092.244944  4.739354e+06    0.000441       0.000448
# 22  Uniswap v2  1848.575115  4.166535e+06    0.000444       0.000447
# 23  Uniswap v2   951.868506  2.159490e+06    0.000441       0.000454
#
#     minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 0        0.000364  81847870.0  12164.056824  2.370735  2021-06-01 00:00:00
# 1        0.000365  93545022.0  13222.888564  2.771741  2021-06-01 01:00:00
# 2        0.000373  75406171.0  11376.355196  2.128097  2021-06-01 02:00:00
# 3        0.000373  77777388.0  11726.195530  2.162176  2021-06-01 03:00:00
# 4        0.000364  55133550.0   5906.889022  1.137330  2021-06-01 04:00:00
# ..            ...         ...           ...       ...                  ...
# 19       0.000445  55564528.0  15933.860401  3.110022  2021-06-30 19:00:00
# 20       0.000438  77398276.0  23525.331816  4.056509  2021-06-30 20:00:00
# 21       0.000437  58432925.0  10918.867905  2.906686  2021-06-30 21:00:00
# 22       0.000440  50647441.0   8766.516144  1.823837  2021-06-30 22:00:00
# 23       0.000438  67268035.0   5771.231117  1.299117  2021-06-30 23:00:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 19                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 20                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 23                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 19                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 20                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 21                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 22                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 23                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [720 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-05-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        may = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        may = may.append(temp)
        #print(nov)


may

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-04-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        apr = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        apr = apr.append(temp)
        #print(nov)


apr

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-03-"""

part2 = """
    "}
    ) {

     
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        mar = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        mar = mar.append(temp)
        #print(nov)


mar

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-02-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,29):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        feb = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        feb = feb.append(temp)
        #print(nov)


feb

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-01-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jan = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jan = jan.append(temp)
        #print(nov)


jan

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v4"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2020-12-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        dec = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        dec = dec.append(temp)
        #print(nov)


dec

# %%
total_dai_eth = nov
total_dai_eth = total_dai_eth.append(octo)
total_dai_eth = total_dai_eth.append(sep)
total_dai_eth = total_dai_eth.append(aug)
total_dai_eth = total_dai_eth.append(jul)
total_dai_eth = total_dai_eth.append(jun)
total_dai_eth = total_dai_eth.append(may)
total_dai_eth = total_dai_eth.append(apr)
total_dai_eth = total_dai_eth.append(mar)
total_dai_eth = total_dai_eth.append(feb)
total_dai_eth = total_dai_eth.append(jan)
total_dai_eth = total_dai_eth.append(dec)
total_dai_eth

# %%
total_dai_eth.to_csv(r'/Users/cameronwalcott/Dropbox/Mac/Desktop/Math 446/Final Data/Uniswapv2-USDC-WETH.csv', index = False)
