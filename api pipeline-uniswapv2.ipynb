# %%
import requests
import pandas as pd


def run_query(query):  # A simple function to use requests.post to make the API call.
    headers = {'X-API-KEY': 'BQYYquuv9iE4tUkIy1vo381YcGGrK5y2'}
    request = requests.post('https://graphql.bitquery.io/',
                            json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed and return code is {}.      {}'.format(request.status_code,
                                                                             query))


part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-11-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        nov = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        nov = nov.append(temp)
        #print(nov)


nov
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   118.516668  5.082524e+05    0.000233       0.000234
# 1    Uniswap v2   302.596943  1.303468e+06    0.000232       0.000234
# 2    Uniswap v2    76.109194  3.278846e+05    0.000232       0.000233
# 3    Uniswap v2    62.638602  2.693400e+05    0.000233       0.000233
# 4    Uniswap v2    34.986286  1.508784e+05    0.000232       0.000233
# ..          ...          ...           ...         ...            ...
# 138  Uniswap v2    43.215605  2.005561e+05    0.000215       0.000216
# 139  Uniswap v2    73.107385  3.399294e+05    0.000215       0.000216
# 140  Uniswap v2    34.082414  1.583307e+05    0.000215       0.000216
# 141  Uniswap v2    66.177500  3.073672e+05    0.000215       0.000216
# 142  Uniswap v2    75.020956  3.476591e+05    0.000216       0.000216
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000232  7534718.0  6679.139820  1.396793  2021-11-01 00:00:00
# 1         0.000231  6786217.0  6342.682067  1.283171  2021-11-01 00:10:00
# 2         0.000231  6848237.0  4937.894003  1.111517  2021-11-01 00:20:00
# 3         0.000231  4448542.0  3801.782428  0.817154  2021-11-01 00:30:00
# 4         0.000231  6087587.0  3287.933551  0.755510  2021-11-01 00:40:00
# ..             ...        ...          ...       ...                  ...
# 138       0.000214  4285312.0  3245.806682  0.628925  2021-11-30 23:10:00
# 139       0.000214  4146809.0  2538.304143  0.507813  2021-11-30 23:20:00
# 140       0.000214  4024278.0  2770.015076  0.522734  2021-11-30 23:30:00
# 141       0.000214  5296036.0  3212.889235  0.670865  2021-11-30 23:40:00
# 142       0.000215  8442920.0  5077.630280  1.033080  2021-11-30 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 138                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 138                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4319 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-10-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        octo = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        octo = octo.append(temp)
        #print(nov)


octo
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   370.436757  1.115445e+06    0.000332       0.000335
# 1    Uniswap v2   308.810547  9.283832e+05    0.000333       0.000334
# 2    Uniswap v2    73.512725  2.220462e+05    0.000331       0.000333
# 3    Uniswap v2   258.479222  7.827014e+05    0.000330       0.000334
# 4    Uniswap v2    38.814166  1.173960e+05    0.000331       0.000332
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   116.252031  4.985605e+05    0.000233       0.000234
# 140  Uniswap v2    98.444917  4.228195e+05    0.000233       0.000234
# 141  Uniswap v2   151.642959  6.514463e+05    0.000233       0.000234
# 142  Uniswap v2    39.718616  1.707673e+05    0.000233       0.000234
# 143  Uniswap v2    68.787348  2.958500e+05    0.000233       0.000234
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000331  2920982.0  3179.818385  0.581660  2021-10-01 00:00:00
# 1         0.000331  6599319.0  3341.909811  0.816861  2021-10-01 00:10:00
# 2         0.000331  5165040.0  2505.468838  0.533073  2021-10-01 00:20:00
# 3         0.000329  6011159.0  2760.811594  0.536484  2021-10-01 00:30:00
# 4         0.000329  3676345.0  1888.770228  0.361083  2021-10-01 00:40:00
# ..             ...        ...          ...       ...                  ...
# 139       0.000232  7626663.0  5626.772324  1.143944  2021-10-31 23:10:00
# 140       0.000232  7566858.0  5021.438820  1.055067  2021-10-31 23:20:00
# 141       0.000232  6629886.0  4585.434251  0.914278  2021-10-31 23:30:00
# 142       0.000232  2494815.0  2375.526998  0.456976  2021-10-31 23:40:00
# 143       0.000231  3346296.0  3479.980753  0.682029  2021-10-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4464 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-09-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        sep = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        sep = sep.append(temp)
        #print(nov)


sep
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   526.506368  1.803838e+06    0.000292       0.000294
# 1    Uniswap v2   163.213094  5.594084e+05    0.000292       0.000293
# 2    Uniswap v2    52.442398  1.799580e+05    0.000291       0.000292
# 3    Uniswap v2   281.301880  9.591647e+05    0.000293       0.000294
# 4    Uniswap v2   270.502985  9.225978e+05    0.000293       0.000294
# ..          ...          ...           ...         ...            ...
# 138  Uniswap v2   216.647819  6.502668e+05    0.000333       0.000334
# 139  Uniswap v2   142.604762  4.265973e+05    0.000334       0.000335
# 140  Uniswap v2    32.243910  9.632094e+04    0.000335       0.000335
# 141  Uniswap v2    41.582127  1.248425e+05    0.000333       0.000335
# 142  Uniswap v2     6.025733  1.810874e+04    0.000333       0.000333
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000290  8140666.0  6836.293083  1.264794  2021-09-01 00:00:00
# 1         0.000290  4050781.0  3620.258972  0.664512  2021-09-01 00:10:00
# 2         0.000291  3758167.0  3458.717237  0.618373  2021-09-01 00:20:00
# 3         0.000290  4544359.0  3229.038289  0.695270  2021-09-01 00:30:00
# 4         0.000291  7897663.0  4551.141638  1.076111  2021-09-01 00:40:00
# ..             ...        ...          ...       ...                  ...
# 138       0.000331  7103602.0  2702.191260  0.586939  2021-09-30 23:00:00
# 139       0.000333  5240633.0  2212.067713  0.467444  2021-09-30 23:10:00
# 140       0.000333  2621119.0  1358.935384  0.260081  2021-09-30 23:20:00
# 141       0.000333  1243277.0   799.170134  0.162463  2021-09-30 23:30:00
# 142       0.000333   656055.0  1922.670248  0.295728  2021-09-30 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 138                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 138                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4318 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-08-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        aug = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        aug = aug.append(temp)
        #print(nov)


aug
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   901.898052  2.280826e+06    0.000395       0.000398
# 1    Uniswap v2   148.211450  3.764138e+05    0.000394       0.000406
# 2    Uniswap v2   392.596958  1.000349e+06    0.000392       0.000397
# 3    Uniswap v2    82.477146  2.104846e+05    0.000392       0.000408
# 4    Uniswap v2   389.171893  9.956731e+05    0.000391       0.000394
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   292.914387  1.001461e+06    0.000292       0.000294
# 140  Uniswap v2   128.206211  4.372781e+05    0.000293       0.000294
# 141  Uniswap v2   297.866109  1.021667e+06    0.000292       0.000293
# 142  Uniswap v2    52.192744  1.790509e+05    0.000291       0.000293
# 143  Uniswap v2   107.358818  3.687418e+05    0.000291       0.000293
#
#      minimum_price         gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000392  16583948.0  4451.663763  0.734668  2021-08-01 00:00:00
# 1         0.000393  12012206.0  1544.319996  0.342216  2021-08-01 00:10:00
# 2         0.000391  11710172.0  1714.678248  0.321457  2021-08-01 00:20:00
# 3         0.000391  13732091.0  1540.215390  0.354976  2021-08-01 00:30:00
# 4         0.000390  11761278.0  1645.695177  0.304894  2021-08-01 00:40:00
# ..             ...         ...          ...       ...                  ...
# 139       0.000291   4519177.0  4336.777527  0.708472  2021-08-31 23:10:00
# 140       0.000292   3137626.0  3368.515650  0.589278  2021-08-31 23:20:00
# 141       0.000291   3305557.0  3808.406487  0.659440  2021-08-31 23:30:00
# 142       0.000290   3417533.0  3287.755342  0.668654  2021-08-31 23:40:00
# 143       0.000290   5581095.0  4185.804956  0.927089  2021-08-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4462 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-07-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jul = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jul = jul.append(temp)
        #print(nov)


jul
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   437.371095  9.891410e+05    0.000442       0.000443
# 1    Uniswap v2   643.193436  1.444176e+06    0.000445       0.000447
# 2    Uniswap v2   101.196438  2.270855e+05    0.000446       0.000447
# 3    Uniswap v2   138.428765  3.116210e+05    0.000444       0.000447
# 4    Uniswap v2    30.260285  6.798808e+04    0.000445       0.000446
# ..          ...          ...           ...         ...            ...
# 138  Uniswap v2   285.110009  7.255349e+05    0.000393       0.000445
# 139  Uniswap v2   396.066436  1.005406e+06    0.000394       0.000396
# 140  Uniswap v2   135.415630  3.448720e+05    0.000393       0.000395
# 141  Uniswap v2   150.516504  3.842827e+05    0.000392       0.000394
# 142  Uniswap v2   380.365087  9.668549e+05    0.000393       0.000395
#
#      minimum_price         gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000438   8509416.0  1035.460386  0.193510  2021-07-01 00:00:00
# 1         0.000442   7751769.0  1159.178871  0.199670  2021-07-01 00:10:00
# 2         0.000444   7307963.0   845.143001  0.170630  2021-07-01 00:20:00
# 3         0.000444   6171607.0   689.590003  0.130585  2021-07-01 00:30:00
# 4         0.000444   6754420.0   797.975008  0.159489  2021-07-01 00:40:00
# ..             ...         ...          ...       ...                  ...
# 138       0.000392  13448292.0  1535.415323  0.435214  2021-07-31 23:10:00
# 139       0.000392  14639385.0  3495.282221  0.649252  2021-07-31 23:20:00
# 140       0.000392  14255808.0  2013.239992  0.398724  2021-07-31 23:30:00
# 141       0.000391  11912789.0  1025.629999  0.265901  2021-07-31 23:40:00
# 142       0.000391  14941612.0  2014.499301  0.430645  2021-07-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 138                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 138                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4463 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-06-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jun = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jun = jun.append(temp)
        #print(nov)


jun
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2  1011.139137  2.748298e+06    0.000368       0.000371
# 1    Uniswap v2   793.516332  2.168562e+06    0.000366       0.000379
# 2    Uniswap v2   433.760727  1.180929e+06    0.000367       0.000369
# 3    Uniswap v2   234.304861  6.374011e+05    0.000368       0.000386
# 4    Uniswap v2   125.513169  3.423982e+05    0.000367       0.000369
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   138.829313  3.146248e+05    0.000441       0.000444
# 140  Uniswap v2    26.589919  6.023600e+04    0.000441       0.000454
# 141  Uniswap v2   361.313744  8.205963e+05    0.000440       0.000453
# 142  Uniswap v2   122.725972  2.795539e+05    0.000439       0.000442
# 143  Uniswap v2    41.140713  9.349673e+04    0.000440       0.000441
#
#      minimum_price         gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000365  15058010.0  3114.185731  0.495280  2021-06-01 00:00:00
# 1         0.000364  17425772.0  2319.060165  0.513522  2021-06-01 00:10:00
# 2         0.000366  14178831.0  1845.981559  0.403708  2021-06-01 00:20:00
# 3         0.000365  11364162.0  1829.600647  0.348085  2021-06-01 00:30:00
# 4         0.000366  11960246.0  1538.200009  0.315997  2021-06-01 00:40:00
# ..             ...         ...          ...       ...                  ...
# 139       0.000441  12727958.0  1099.427358  0.234390  2021-06-30 23:10:00
# 140       0.000440   8060649.0   720.626007  0.146139  2021-06-30 23:20:00
# 141       0.000439  12422903.0   974.095242  0.251397  2021-06-30 23:30:00
# 142       0.000438  11706739.0  1030.746902  0.234741  2021-06-30 23:40:00
# 143       0.000438  10895963.0   883.197745  0.194406  2021-06-30 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4320 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-05-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        may = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        may = may.append(temp)
        #print(nov)


may
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   627.414814  1.736602e+06    0.000361       0.000363
# 1    Uniswap v2   177.882366  4.931228e+05    0.000361       0.000362
# 2    Uniswap v2   143.015072  3.962918e+05    0.000361       0.000362
# 3    Uniswap v2   165.730522  4.599687e+05    0.000360       0.000362
# 4    Uniswap v2   138.718577  3.836967e+05    0.000362       0.000362
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   410.982557  1.096899e+06    0.000375       0.000378
# 140  Uniswap v2   851.506575  2.286954e+06    0.000372       0.000376
# 141  Uniswap v2   497.047717  1.342704e+06    0.000370       0.000383
# 142  Uniswap v2   835.123897  2.263988e+06    0.000369       0.000377
# 143  Uniswap v2   213.607075  5.782698e+05    0.000369       0.000371
#
#      minimum_price         gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000360  12944048.0  3387.884421  0.628539  2021-05-01 00:00:00
# 1         0.000360  14034503.0  3276.049986  0.635731  2021-05-01 00:10:00
# 2         0.000360  10175410.0  2324.169224  0.456300  2021-05-01 00:20:00
# 3         0.000359   8983965.0  2172.971438  0.417181  2021-05-01 00:30:00
# 4         0.000360  12606429.0  2930.160976  0.555444  2021-05-01 00:40:00
# ..             ...         ...          ...       ...                  ...
# 139       0.000373   9888226.0  1577.907197  0.383261  2021-05-31 23:10:00
# 140       0.000370  17014047.0  2668.610212  0.474848  2021-05-31 23:20:00
# 141       0.000369  15885989.0  1932.073355  0.438575  2021-05-31 23:30:00
# 142       0.000367  23838761.0  3217.550465  0.734725  2021-05-31 23:40:00
# 143       0.000368  17398597.0  2219.574397  0.498649  2021-05-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4464 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-04-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        apr = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        apr = apr.append(temp)
        #print(nov)


apr
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   743.166807  1.434260e+06    0.000518       0.000522
# 1    Uniswap v2   222.745158  4.288659e+05    0.000519       0.000521
# 2    Uniswap v2  1551.801702  3.013447e+06    0.000515       0.000521
# 3    Uniswap v2   756.669541  1.461616e+06    0.000518       0.000520
# 4    Uniswap v2   297.583861  5.728045e+05    0.000520       0.000532
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   193.758871  5.325778e+05    0.000364       0.000365
# 140  Uniswap v2   270.572279  7.460768e+05    0.000363       0.000365
# 141  Uniswap v2   427.349488  1.182008e+06    0.000362       0.000364
# 142  Uniswap v2   347.048074  9.602230e+05    0.000361       0.000363
# 143  Uniswap v2   115.100533  3.189462e+05    0.000361       0.000363
#
#      minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 0         0.000516  11539492.0  14357.254685  2.728407  2021-04-01 00:00:00
# 1         0.000516   7282226.0   9572.199973  1.761398  2021-04-01 00:10:00
# 2         0.000512  11496675.0  22904.069046  4.206634  2021-04-01 00:20:00
# 3         0.000515  11890318.0  16992.149930  3.223662  2021-04-01 00:30:00
# 4         0.000517  10781067.0  14163.664699  2.716399  2021-04-01 00:40:00
# ..             ...         ...           ...       ...                  ...
# 139       0.000363  11447848.0   2693.816668  0.509946  2021-04-30 23:10:00
# 140       0.000362  13330379.0   3222.443479  0.638720  2021-04-30 23:20:00
# 141       0.000360  15109941.0   3679.122629  0.640381  2021-04-30 23:30:00
# 142       0.000360   9030557.0   2264.349983  0.390110  2021-04-30 23:40:00
# 143       0.000360  10517356.0   2427.492815  0.475380  2021-04-30 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4320 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-03-"""

part2 = """
    "}
    ) {

     
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        mar = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        mar = mar.append(temp)
        #print(nov)


mar
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2  1157.068996  1.644895e+06    0.000703       0.000707
# 1    Uniswap v2  2168.852077  3.106566e+06    0.000698       0.000708
# 2    Uniswap v2   601.439714  8.693630e+05    0.000692       0.000696
# 3    Uniswap v2   428.185389  6.201123e+05    0.000690       0.000695
# 4    Uniswap v2  2919.617167  4.262154e+06    0.000685       0.000693
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   490.031295  9.380270e+05    0.000522       0.000526
# 140  Uniswap v2   500.978788  9.610697e+05    0.000521       0.000525
# 141  Uniswap v2   450.011701  8.593438e+05    0.000524       0.000535
# 142  Uniswap v2   920.661927  1.762349e+06    0.000522       0.000525
# 143  Uniswap v2   251.571842  4.832416e+05    0.000521       0.000524
#
#      minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 0         0.000699  11431105.0   7590.498517  1.338713  2021-03-01 00:00:00
# 1         0.000692  20198699.0  10738.150814  2.104417  2021-03-01 00:10:00
# 2         0.000689  12372790.0   6305.303626  1.272192  2021-03-01 00:20:00
# 3         0.000689  11235964.0   6806.344385  1.239048  2021-03-01 00:30:00
# 4         0.000677  19032346.0  10048.525025  2.294827  2021-03-01 00:40:00
# ..             ...         ...           ...       ...                  ...
# 139       0.000521   9558602.0  12998.146294  2.330595  2021-03-31 23:10:00
# 140       0.000519  10851462.0  14473.541566  2.603240  2021-03-31 23:20:00
# 141       0.000519  11642120.0  14298.633208  2.617798  2021-03-31 23:30:00
# 142       0.000519  12725304.0  12456.140030  2.870284  2021-03-31 23:40:00
# 143       0.000519   9902984.0  11680.285278  2.094470  2021-03-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4464 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-02-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,29):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        feb = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        feb = feb.append(temp)
        #print(nov)


feb
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2  2334.278988  3.023915e+06    0.000772       0.000779
# 1    Uniswap v2  1945.068162  2.496763e+06    0.000779       0.000784
# 2    Uniswap v2  2073.304310  2.641830e+06    0.000785       0.000791
# 3    Uniswap v2  1590.635436  2.033260e+06    0.000782       0.000789
# 4    Uniswap v2  3899.783844  4.954827e+06    0.000787       0.000791
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   909.708496  1.307747e+06    0.000696       0.000700
# 140  Uniswap v2   589.919741  8.497952e+05    0.000694       0.000697
# 141  Uniswap v2   836.661983  1.198299e+06    0.000698       0.000701
# 142  Uniswap v2  1176.567609  1.671213e+06    0.000704       0.000709
# 143  Uniswap v2   740.454660  1.050029e+06    0.000705       0.000709
#
#      minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 0         0.000761  12647176.0  18002.977096  2.848530  2021-02-01 00:00:00
# 1         0.000773  19307046.0  18514.212422  3.712366  2021-02-01 00:10:00
# 2         0.000777  19277028.0  18950.012772  3.599506  2021-02-01 00:20:00
# 3         0.000778  17713673.0  18868.220674  3.584202  2021-02-01 00:30:00
# 4         0.000776  26254317.0  14036.352524  3.691868  2021-02-01 00:40:00
# ..             ...         ...           ...       ...                  ...
# 139       0.000691  18364149.0   7057.444987  1.795563  2021-02-28 23:10:00
# 140       0.000691  14417432.0   6418.166063  1.335846  2021-02-28 23:20:00
# 141       0.000693  21210666.0   7469.477233  1.821094  2021-02-28 23:30:00
# 142       0.000697  17370450.0   6608.854606  1.679034  2021-02-28 23:40:00
# 143       0.000702  21075686.0   7302.744338  1.786500  2021-02-28 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4031 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-01-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jan = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jan = jan.append(temp)
        #print(nov)


jan
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   336.608969  2.480885e+05    0.001357       0.001362
# 1    Uniswap v2   546.199138  4.003593e+05    0.001364       0.001369
# 2    Uniswap v2   622.206999  4.556505e+05    0.001366       0.001372
# 3    Uniswap v2   244.923131  1.796920e+05    0.001363       0.001370
# 4    Uniswap v2   153.447924  1.125107e+05    0.001364       0.001368
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   687.821047  9.044509e+05    0.000760       0.000764
# 140  Uniswap v2   444.085430  5.853723e+05    0.000759       0.000777
# 141  Uniswap v2   655.080713  8.631019e+05    0.000759       0.000762
# 142  Uniswap v2   250.965378  3.312210e+05    0.000758       0.000761
# 143  Uniswap v2  1325.552715  1.736914e+06    0.000763       0.000766
#
#      minimum_price         gas      gasPrice  gasValue  timeInterval.minute  \
# 0         0.001352   9347745.0   3277.882765  0.654009  2021-01-01 00:00:00
# 1         0.001354  12407786.0   3741.438980  0.840585  2021-01-01 00:10:00
# 2         0.001358  14413694.0   3924.591210  0.958982  2021-01-01 00:20:00
# 3         0.001359  10850356.0   4238.223122  0.859640  2021-01-01 00:30:00
# 4         0.001359  12358922.0   4009.050010  0.857527  2021-01-01 00:40:00
# ..             ...         ...           ...       ...                  ...
# 139       0.000757  11763707.0   9368.368333  1.715483  2021-01-31 23:10:00
# 140       0.000756  11975289.0   7564.817089  1.698529  2021-01-31 23:20:00
# 141       0.000756  17439291.0   8590.172054  2.235977  2021-01-31 23:30:00
# 142       0.000756  14690094.0   7586.743058  1.867200  2021-01-31 23:40:00
# 143       0.000756  14364283.0  10285.745881  2.025138  2021-01-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4464 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Uniswap v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2020-12-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        dec = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        dec = dec.append(temp)
        #print(nov)


dec
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   541.476615  3.323784e+05    0.001629       0.001634
# 1    Uniswap v2   573.295650  3.516968e+05    0.001630       0.001637
# 2    Uniswap v2   136.137225  8.358275e+04    0.001629       0.001637
# 3    Uniswap v2   472.345531  2.884555e+05    0.001637       0.001643
# 4    Uniswap v2   801.057844  4.863999e+05    0.001647       0.001654
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2  1733.893065  1.278063e+06    0.001357       0.001363
# 140  Uniswap v2   168.192967  1.243757e+05    0.001352       0.001357
# 141  Uniswap v2   229.715717  1.699151e+05    0.001352       0.001357
# 142  Uniswap v2   461.191533  3.397839e+05    0.001357       0.001361
# 143  Uniswap v2   149.023952  1.097163e+05    0.001358       0.001362
#
#      minimum_price         gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.001615   7070868.0  2397.735236  0.494473  2020-12-01 00:00:00
# 1         0.001620   8633467.0  3485.584773  0.734511  2020-12-01 00:10:00
# 2         0.001625   7633577.0  2524.644086  0.605936  2020-12-01 00:20:00
# 3         0.001625   9023059.0  3208.184074  0.767034  2020-12-01 00:30:00
# 4         0.001634  11261028.0  4058.264543  0.991493  2020-12-01 00:40:00
# ..             ...         ...          ...       ...                  ...
# 139       0.001347  12867640.0  4079.636087  0.728763  2020-12-31 23:10:00
# 140       0.001346  12033342.0  3421.367398  0.696851  2020-12-31 23:20:00
# 141       0.001346  13077770.0  3664.632414  0.722675  2020-12-31 23:30:00
# 142       0.001349  18633518.0  5713.277817  1.111558  2020-12-31 23:40:00
# 143       0.001353  12983087.0  3948.513829  0.706608  2020-12-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [4464 rows x 14 columns]

# %%
total_dai_eth = nov
total_dai_eth = total_dai_eth.append(octo)
total_dai_eth = total_dai_eth.append(sep)
total_dai_eth = total_dai_eth.append(aug)
total_dai_eth = total_dai_eth.append(jul)
total_dai_eth = total_dai_eth.append(jun)
total_dai_eth = total_dai_eth.append(may)
total_dai_eth = total_dai_eth.append(apr)
total_dai_eth = total_dai_eth.append(mar)
total_dai_eth = total_dai_eth.append(feb)
total_dai_eth = total_dai_eth.append(jan)
total_dai_eth = total_dai_eth.append(dec)
total_dai_eth
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   118.516668  5.082524e+05    0.000233       0.000234
# 1    Uniswap v2   302.596943  1.303468e+06    0.000232       0.000234
# 2    Uniswap v2    76.109194  3.278846e+05    0.000232       0.000233
# 3    Uniswap v2    62.638602  2.693400e+05    0.000233       0.000233
# 4    Uniswap v2    34.986286  1.508784e+05    0.000232       0.000233
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2  1733.893065  1.278063e+06    0.001357       0.001363
# 140  Uniswap v2   168.192967  1.243757e+05    0.001352       0.001357
# 141  Uniswap v2   229.715717  1.699151e+05    0.001352       0.001357
# 142  Uniswap v2   461.191533  3.397839e+05    0.001357       0.001361
# 143  Uniswap v2   149.023952  1.097163e+05    0.001358       0.001362
#
#      minimum_price         gas     gasPrice  gasValue  timeInterval.minute  \
# 0         0.000232   7534718.0  6679.139820  1.396793  2021-11-01 00:00:00
# 1         0.000231   6786217.0  6342.682067  1.283171  2021-11-01 00:10:00
# 2         0.000231   6848237.0  4937.894003  1.111517  2021-11-01 00:20:00
# 3         0.000231   4448542.0  3801.782428  0.817154  2021-11-01 00:30:00
# 4         0.000231   6087587.0  3287.933551  0.755510  2021-11-01 00:40:00
# ..             ...         ...          ...       ...                  ...
# 139       0.001347  12867640.0  4079.636087  0.728763  2020-12-31 23:10:00
# 140       0.001346  12033342.0  3421.367398  0.696851  2020-12-31 23:20:00
# 141       0.001346  13077770.0  3664.632414  0.722675  2020-12-31 23:30:00
# 142       0.001349  18633518.0  5713.277817  1.111558  2020-12-31 23:40:00
# 143       0.001353  12983087.0  3948.513829  0.706608  2020-12-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 139                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 140                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 141                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 142                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 143                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 139                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 140                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 141                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 142                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 143                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [48233 rows x 14 columns]

# %%
total_dai_eth.to_csv(r'/Users/cameronwalcott/Dropbox/Mac/Desktop/Math 446/Final Data/USDC-WETH/Uniswapv2-USDC-WETH.csv', index = False)
