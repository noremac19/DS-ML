# %%
import requests
import pandas as pd


def run_query(query):  # A simple function to use requests.post to make the API call.
    headers = {'X-API-KEY': 'BQYYquuv9iE4tUkIy1vo381YcGGrK5y2'}
    request = requests.post('https://graphql.bitquery.io/',
                            json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed and return code is {}.      {}'.format(request.status_code,
                                                                             query))


part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"} 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-11-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        nov = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        nov = nov.append(temp)
        #print(nov)


nov
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2    30.774505  131897.357470    0.000233       0.000234
# 1    Uniswap v2   146.972517  633957.469884    0.000232       0.000232
# 2    Uniswap v2     6.220669   26894.685643    0.000231       0.000232
# 3    Uniswap v2     6.214562   26782.443082    0.000232       0.000232
# 4    Uniswap v2    14.578785   62871.263586    0.000232       0.000233
# ..          ...          ...            ...         ...            ...
# 137  Uniswap v2    25.107010  116359.352287    0.000216       0.000216
# 138  Uniswap v2    63.125647  293595.613256    0.000215       0.000216
# 139  Uniswap v2    17.883061   83008.274779    0.000215       0.000216
# 140  Uniswap v2    42.241526  195924.724524    0.000216       0.000216
# 141  Uniswap v2    19.019686   88134.067778    0.000216       0.000216
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-10-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        octo = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        octo = octo.append(temp)
        #print(nov)


octo
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   231.455774  696968.625993    0.000332       0.000335
# 1    Uniswap v2   282.793119  849917.848234    0.000333       0.000334
# 2    Uniswap v2    52.441746  158503.212255    0.000331       0.000333
# 3    Uniswap v2   154.478398  467778.921487    0.000330       0.000333
# 4    Uniswap v2     9.266752   28028.331791    0.000331       0.000331
# ..          ...          ...            ...         ...            ...
# 139  Uniswap v2     6.841962   29311.880177    0.000233       0.000234
# 140  Uniswap v2    13.209631   56805.730076    0.000233       0.000234
# 141  Uniswap v2    23.939019  102887.134615    0.000233       0.000234
# 142  Uniswap v2     7.727978   33137.933182    0.000233       0.000234
# 143  Uniswap v2    29.134220  124678.034950    0.000234       0.000234
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-09-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        sep = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        sep = sep.append(temp)
        #print(nov)


sep
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   274.407066  939747.758966    0.000292       0.000294
# 1    Uniswap v2   130.886537  448505.290035    0.000292       0.000293
# 2    Uniswap v2    28.915644   99254.977144    0.000291       0.000292
# 3    Uniswap v2     4.609188   15860.033351    0.000291       0.000291
# 4    Uniswap v2   200.624711  684165.445374    0.000293       0.000294
# ..          ...          ...            ...         ...            ...
# 138  Uniswap v2   137.609872  412924.675314    0.000333       0.000334
# 139  Uniswap v2    67.312526  201282.138669    0.000334       0.000335
# 140  Uniswap v2     3.787198   11379.042632    0.000333       0.000333
# 141  Uniswap v2     0.651031    1944.474069    0.000335       0.000335
# 142  Uniswap v2     5.027905   15108.739963    0.000333       0.000333
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-08-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        aug = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        aug = aug.append(temp)
        #print(nov)


aug
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   454.122676  1.148635e+06    0.000395       0.000397
# 1    Uniswap v2    47.369645  1.204462e+05    0.000393       0.000396
# 2    Uniswap v2   196.677065  5.015407e+05    0.000392       0.000395
# 3    Uniswap v2     5.672024  1.449814e+04    0.000391       0.000394
# 4    Uniswap v2   214.261653  5.484367e+05    0.000391       0.000394
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   189.697585  6.489941e+05    0.000292       0.000294
# 140  Uniswap v2    14.909897  5.083600e+04    0.000293       0.000293
# 141  Uniswap v2   118.483424  4.070305e+05    0.000291       0.000292
# 142  Uniswap v2    32.693421  1.122494e+05    0.000291       0.000292
# 143  Uniswap v2    13.462113  4.624710e+04    0.000291       0.000292
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-07-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jul = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jul = jul.append(temp)
        #print(nov)


jul
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   226.301204  511849.396393    0.000442       0.000443
# 1    Uniswap v2   331.135617  743240.453191    0.000446       0.000447
# 2    Uniswap v2    32.218616   72413.428432    0.000445       0.000447
# 3    Uniswap v2    84.567956  190386.219033    0.000444       0.000447
# 4    Uniswap v2     7.382717   16582.622561    0.000445       0.000446
# ..          ...          ...            ...         ...            ...
# 138  Uniswap v2   119.801194  305273.405743    0.000392       0.000395
# 139  Uniswap v2    24.957211   63644.698028    0.000392       0.000394
# 140  Uniswap v2    27.533511   70216.888570    0.000392       0.000394
# 141  Uniswap v2    43.177487  110309.453372    0.000391       0.000394
# 142  Uniswap v2   223.685878  568426.409348    0.000394       0.000395
#
#      minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-06-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jun = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jun = jun.append(temp)
        #print(nov)


jun
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   585.909873  1.591246e+06    0.000368       0.000371
# 1    Uniswap v2   620.338999  1.696566e+06    0.000366       0.000368
# 2    Uniswap v2   192.760596  5.249217e+05    0.000367       0.000369
# 3    Uniswap v2    86.536192  2.351416e+05    0.000368       0.000369
# 4    Uniswap v2    57.439713  1.568145e+05    0.000366       0.000368
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2    79.988834  1.812807e+05    0.000441       0.000444
# 140  Uniswap v2     2.319853  5.243564e+03    0.000442       0.000443
# 141  Uniswap v2   149.996301  3.410072e+05    0.000440       0.000443
# 142  Uniswap v2    45.372759  1.033629e+05    0.000439       0.000442
# 143  Uniswap v2     8.949815  2.030901e+04    0.000441       0.000441
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-05-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        may = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        may = may.append(temp)
        #print(nov)


may
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   332.885472  9.209199e+05    0.000361       0.000363
# 1    Uniswap v2     9.080343  2.520408e+04    0.000360       0.000362
# 2    Uniswap v2     1.667412  4.606343e+03    0.000362       0.000362
# 3    Uniswap v2     0.637893  1.772822e+03    0.000360       0.000360
# 4    Uniswap v2     8.381373  2.319385e+04    0.000361       0.000362
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   214.994474  5.738547e+05    0.000375       0.000377
# 140  Uniswap v2   417.084342  1.120424e+06    0.000372       0.000375
# 141  Uniswap v2   330.608901  8.930795e+05    0.000370       0.000372
# 142  Uniswap v2   590.518003  1.600979e+06    0.000369       0.000371
# 143  Uniswap v2    97.950802  2.653107e+05    0.000369       0.000370
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-04-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        apr = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        apr = apr.append(temp)
        #print(nov)


apr
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   285.684890  551468.204956    0.000518       0.000520
# 1    Uniswap v2    75.416173  145325.561510    0.000519       0.000520
# 2    Uniswap v2   294.682400  570159.825781    0.000517       0.000520
# 3    Uniswap v2   102.253001  197129.678878    0.000519       0.000519
# 4    Uniswap v2    11.659786   22437.438353    0.000520       0.000520
# ..          ...          ...            ...         ...            ...
# 138  Uniswap v2    18.209336   49933.695477    0.000365       0.000365
# 139  Uniswap v2    93.782908  258652.100071    0.000363       0.000365
# 140  Uniswap v2   148.799132  411899.830729    0.000361       0.000363
# 141  Uniswap v2   206.715107  571859.126801    0.000361       0.000363
# 142  Uniswap v2    21.304125   59075.953814    0.000361       0.000362
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-03-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        mar = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        mar = mar.append(temp)
        #print(nov)


mar
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   314.555619  4.468855e+05    0.000704       0.000707
# 1    Uniswap v2  1053.123292  1.511715e+06    0.000697       0.000707
# 2    Uniswap v2    40.372756  5.833944e+04    0.000692       0.000695
# 3    Uniswap v2   120.653793  1.747496e+05    0.000690       0.000695
# 4    Uniswap v2   361.262856  5.236588e+05    0.000690       0.000693
# ..          ...          ...           ...         ...            ...
# 137  Uniswap v2   155.336448  2.975346e+05    0.000522       0.000525
# 138  Uniswap v2   163.769070  3.145491e+05    0.000521       0.000524
# 139  Uniswap v2    58.276906  1.117765e+05    0.000521       0.000523
# 140  Uniswap v2    12.598471  2.410038e+04    0.000523       0.000523
# 141  Uniswap v2     2.222022  4.249897e+03    0.000523       0.000523
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-02-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,29):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        feb = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        feb = feb.append(temp)
        #print(nov)


feb
# Out:
#        protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2   989.989011  1.284111e+06    0.000771       0.000777
# 1    Uniswap v2   265.215179  3.408316e+05    0.000778       0.000780
# 2    Uniswap v2   521.262682  6.648346e+05    0.000784       0.000786
# 3    Uniswap v2   369.586420  4.725694e+05    0.000782       0.000788
# 4    Uniswap v2  1820.845126  2.313676e+06    0.000787       0.000790
# ..          ...          ...           ...         ...            ...
# 139  Uniswap v2   137.524839  1.979292e+05    0.000695       0.000696
# 140  Uniswap v2    88.119382  1.265315e+05    0.000696       0.000697
# 141  Uniswap v2   380.416658  5.446628e+05    0.000698       0.000701
# 142  Uniswap v2   398.417281  5.659803e+05    0.000704       0.000706
# 143  Uniswap v2   245.347396  3.482599e+05    0.000704       0.000708
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-01-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jan = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jan = jan.append(temp)
        #print(nov)


jan
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2     8.307096    6103.809960    0.001361       0.001361
# 1    Uniswap v2   181.119067  132778.077581    0.001364       0.001366
# 2    Uniswap v2   308.721184  226043.853583    0.001366       0.001372
# 3    Uniswap v2    18.290398   13430.932975    0.001362       0.001369
# 4    Uniswap v2    21.899980   16097.399148    0.001360       0.001368
# ..          ...          ...            ...         ...            ...
# 137  Uniswap v2   181.474886  239259.354571    0.000758       0.000764
# 138  Uniswap v2   139.332335  183522.196468    0.000759       0.000762
# 139  Uniswap v2   192.970412  253867.089303    0.000760       0.000762
# 140  Uniswap v2   120.956555  159777.402433    0.000757       0.000761
# 141  Uniswap v2   177.561590  233295.074486    0.000761       0.000762
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
part1 = """
{
  ethereum {
    dexTrades(
    exchangeName: {is: "SushiSwap"}, 
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2020-12-"""

part2 = """
    "}
    ) {

      protocol
      timeInterval {
        minute(count: 10)
      }
      
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        dec = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        dec = dec.append(temp)
        #print(nov)


dec
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2    87.619093   53752.603769    0.001630       0.001632
# 1    Uniswap v2    97.965314   59956.397234    0.001634       0.001636
# 2    Uniswap v2     6.630910    4053.161120    0.001636       0.001636
# 3    Uniswap v2    83.599132   51052.721485    0.001638       0.001638
# 4    Uniswap v2   352.370397  214058.889791    0.001646       0.001651
# ..          ...          ...            ...         ...            ...
# 137  Uniswap v2    78.880008   58480.866585    0.001349       0.001356
# 138  Uniswap v2     9.140205    6765.039579    0.001351       0.001355
# 139  Uniswap v2    71.124667   52770.545039    0.001348       0.001355
# 140  Uniswap v2   158.319290  116669.592860    0.001357       0.001360
# 141  Uniswap v2    11.802081    8674.503601    0.001361       0.001361
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
total_dai_eth = nov
total_dai_eth = total_dai_eth.append(octo)
total_dai_eth = total_dai_eth.append(sep)
total_dai_eth = total_dai_eth.append(aug)
total_dai_eth = total_dai_eth.append(jul)
total_dai_eth = total_dai_eth.append(jun)
total_dai_eth = total_dai_eth.append(may)
# total_dai_eth = total_dai_eth.append(apr)
# total_dai_eth = total_dai_eth.append(mar)
# total_dai_eth = total_dai_eth.append(feb)
# total_dai_eth = total_dai_eth.append(jan)
# total_dai_eth = total_dai_eth.append(dec)
total_dai_eth
# Out:
#        protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Uniswap v2    30.774505  131897.357470    0.000233       0.000234
# 1    Uniswap v2   146.972517  633957.469884    0.000232       0.000232
# 2    Uniswap v2     6.220669   26894.685643    0.000231       0.000232
# 3    Uniswap v2     6.214562   26782.443082    0.000232       0.000232
# 4    Uniswap v2    14.578785   62871.263586    0.000232       0.000233
# ..          ...          ...            ...         ...            ...
# 137  Uniswap v2    78.880008   58480.866585    0.001349       0.001356
# 138  Uniswap v2     9.140205    6765.039579    0.001351       0.001355
# 139  Uniswap v2    71.124667   52770.545039    0.001348       0.001355
# 140  Uniswap v2   158.319290  116669.592860    0.001357       0.001360
# 141  Uniswap v2    11.802081    8674.503601    0.001361       0.001361
#
#      minimum_price        gas     gasPrice  gasValue  timeInterval.minute  \
# ...

# %%
total_dai_eth.to_csv(r'/Users/cameronwalcott/Dropbox/Mac/Desktop/Math 446/Final Data/USDC-WETH/SushiSwap-USDC-WETH.csv', index = False)
