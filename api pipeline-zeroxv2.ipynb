# %%
import requests
import pandas as pd


def run_query(query):  # A simple function to use requests.post to make the API call.
    headers = {'X-API-KEY': 'BQYYquuv9iE4tUkIy1vo381YcGGrK5y2'}
    request = requests.post('https://graphql.bitquery.io/',
                            json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed and return code is {}.      {}'.format(request.status_code,
                                                                             query))


part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-11-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        nov = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        nov = nov.append(temp)
        #print(nov)


nov
# Out:
#              protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2   118.219949  5.006138e+05    0.000236       0.000236
# 1   Zerox Exchange v2     0.297375  1.261799e+03    0.000236       0.000236
# 2   Zerox Exchange v2     0.490669  2.083576e+03    0.000235       0.000236
# 3   Zerox Exchange v2     9.912500  4.177322e+04    0.000237       0.000237
# 4   Zerox Exchange v2     0.247812  1.047225e+03    0.000237       0.000237
# ..                ...          ...           ...         ...            ...
# 4   Zerox Exchange v2    57.123325  2.687208e+05    0.000213       0.000213
# 5   Zerox Exchange v2   108.921270  5.000853e+05    0.000218       0.000218
# 6   Zerox Exchange v2    64.899239  2.976825e+05    0.000218       0.000218
# 7   Zerox Exchange v2    30.000000  1.399180e+05    0.000214       0.000214
# 8   Zerox Exchange v2   287.298378  1.343721e+06    0.000214       0.000214
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000236   315148.0  141.164216  0.044488  2021-11-01 03:30:00
# 1        0.000236   252514.0   95.195021  0.024038  2021-11-01 05:20:00
# 2        0.000235   504980.0  239.196946  0.060395  2021-11-01 05:40:00
# 3        0.000237   230567.0  126.658462  0.029203  2021-11-01 06:10:00
# 4        0.000237   252514.0   99.040567  0.025009  2021-11-01 06:20:00
# ..            ...        ...         ...       ...                  ...
# 4        0.000213  1065551.0  150.560768  0.160430  2021-11-30 15:20:00
# 5        0.000218   432296.0  259.199992  0.112051  2021-11-30 16:10:00
# 6        0.000218   369058.0  122.650493  0.045265  2021-11-30 17:30:00
# 7        0.000214   413944.0  144.158540  0.059674  2021-11-30 18:40:00
# 8        0.000214  1477084.0  115.542811  0.170666  2021-11-30 18:50:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 8                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 5                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 6                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 7                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 8                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [990 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-10-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        octo = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        octo = octo.append(temp)
        #print(nov)


octo
# Out:
#              protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2    96.675600  288547.115819    0.000335       0.000335
# 1   Zerox Exchange v2     5.803714   17382.769937    0.000334       0.000334
# 2   Zerox Exchange v2    49.500322  148500.000000    0.000333       0.000333
# 3   Zerox Exchange v2     0.398671    1200.000000    0.000332       0.000332
# 4   Zerox Exchange v2     5.413510   16420.786064    0.000330       0.000330
# ..                ...          ...            ...         ...            ...
# 14  Zerox Exchange v2     4.956250   20974.991820    0.000236       0.000236
# 15  Zerox Exchange v2    11.599799   50000.000000    0.000232       0.000232
# 16  Zerox Exchange v2     1.060823    4567.000000    0.000232       0.000232
# 17  Zerox Exchange v2     4.460625   19221.044920    0.000232       0.000232
# 18  Zerox Exchange v2     0.594750    2556.206861    0.000233       0.000233
#
#     minimum_price       gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000335  750161.0   87.431938  0.065588  2021-10-01 02:50:00
# 1        0.000334  246183.0   98.974736  0.024366  2021-10-01 03:00:00
# 2        0.000333  578933.0   85.946352  0.049757  2021-10-01 03:50:00
# 3        0.000332  246106.0   49.000002  0.012059  2021-10-01 06:30:00
# 4        0.000330  861397.0   54.515421  0.046959  2021-10-01 07:10:00
# ..            ...       ...         ...       ...                  ...
# 14       0.000236  252538.0  144.509305  0.036494  2021-10-31 18:10:00
# 15       0.000232  246154.0  145.000006  0.035692  2021-10-31 21:50:00
# 16       0.000232  315148.0  130.577490  0.041151  2021-10-31 22:10:00
# 17       0.000232  238351.0  149.527462  0.035640  2021-10-31 22:30:00
# 18       0.000233  252502.0  269.662405  0.068090  2021-10-31 23:40:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 14                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 15                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 16                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 17                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 18                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 14                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 15                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 16                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 17                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 18                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [781 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-09-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        sep = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        sep = sep.append(temp)
        #print(nov)


sep
# Out:
#              protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2    60.461672  207000.000000    0.000292       0.000292
# 1   Zerox Exchange v2    81.933459  279386.066418    0.000293       0.000293
# 2   Zerox Exchange v2   100.000000  339372.539682    0.000295       0.000295
# 3   Zerox Exchange v2   114.601112  388151.345529    0.000295       0.000296
# 4   Zerox Exchange v2   107.258894  362805.887634    0.000296       0.000296
# ..                ...          ...            ...         ...            ...
# 20  Zerox Exchange v2    50.000000  150356.136287    0.000333       0.000333
# 21  Zerox Exchange v2    72.589497  216933.750000    0.000335       0.000335
# 22  Zerox Exchange v2   269.640000  799106.445692    0.000337       0.000338
# 23  Zerox Exchange v2     0.363200    1078.383522    0.000337       0.000337
# 24  Zerox Exchange v2   260.000000  779926.318726    0.000333       0.000333
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000292   281472.0  216.000004  0.060798  2021-09-01 00:00:00
# 1        0.000293   435857.0  281.999999  0.122912  2021-09-01 00:40:00
# 2        0.000295   258119.0  108.888596  0.028106  2021-09-01 00:50:00
# 3        0.000295   810386.0  281.437905  0.107292  2021-09-01 01:00:00
# 4        0.000296   734180.0  211.466166  0.079774  2021-09-01 01:10:00
# ..            ...        ...         ...       ...                  ...
# 20       0.000333   282789.0  108.627149  0.030719  2021-09-30 15:20:00
# 21       0.000335  1316186.0  221.449937  0.143125  2021-09-30 15:40:00
# 22       0.000337  1499800.0  121.228763  0.181819  2021-09-30 16:30:00
# 23       0.000337   301144.0  102.999998  0.031018  2021-09-30 16:40:00
# 24       0.000333  2645520.0  121.707045  0.321978  2021-09-30 19:50:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 20                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 21                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 22                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 23                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 24                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 20                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 21                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 22                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 23                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 24                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [908 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-08-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        aug = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        aug = aug.append(temp)
        #print(nov)


aug
# Out:
#              protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2   125.641338  318608.551180    0.000394       0.000395
# 1   Zerox Exchange v2     1.411826    3580.181999    0.000394       0.000394
# 2   Zerox Exchange v2    89.904296  229124.687697    0.000392       0.000393
# 3   Zerox Exchange v2     8.328020   21216.833689    0.000393       0.000393
# 4   Zerox Exchange v2    26.656596   68018.846572    0.000392       0.000393
# ..                ...          ...            ...         ...            ...
# 38  Zerox Exchange v2    19.825000   67186.920525    0.000295       0.000295
# 39  Zerox Exchange v2    12.173834   41133.532943    0.000296       0.000296
# 40  Zerox Exchange v2    39.577101  133670.241045    0.000296       0.000296
# 41  Zerox Exchange v2    20.484001   70000.000000    0.000293       0.000293
# 42  Zerox Exchange v2    39.707316  136729.302700    0.000290       0.000290
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000394  3274620.0  212.999999  0.101023  2021-08-01 00:00:00
# 1        0.000394   319498.0   24.199999  0.007732  2021-08-01 00:10:00
# 2        0.000392  2200544.0  172.000000  0.061473  2021-08-01 00:20:00
# 3        0.000392   711064.0   56.000000  0.019829  2021-08-01 00:30:00
# 4        0.000390  2385930.0  110.999998  0.066735  2021-08-01 00:40:00
# ..            ...        ...         ...       ...                  ...
# 38       0.000295   346542.0  115.999998  0.040199  2021-08-31 22:20:00
# 39       0.000296   543905.0  110.011040  0.059836  2021-08-31 22:30:00
# 40       0.000296   762216.0  223.089697  0.085285  2021-08-31 22:40:00
# 41       0.000293   251990.0   96.361562  0.024282  2021-08-31 23:00:00
# 42       0.000290   507644.0  195.350200  0.099168  2021-08-31 23:30:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 38                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 39                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 40                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 41                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 42                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 38                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 39                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 40                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 41                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 42                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [1839 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-07-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jul = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jul = jul.append(temp)
        #print(nov)


jul
# Out:
#               protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0    Zerox Exchange v2    60.060710  1.354545e+05    0.000443       0.000444
# 1    Zerox Exchange v2    12.053600  2.709258e+04    0.000445       0.000445
# 2    Zerox Exchange v2     1.297148  2.920964e+03    0.000444       0.000444
# 3    Zerox Exchange v2    21.642574  4.834442e+04    0.000448       0.000448
# 4    Zerox Exchange v2     4.552923  1.005536e+04    0.000453       0.000453
# ..                 ...          ...           ...         ...            ...
# 113  Zerox Exchange v2    80.918771  2.057405e+05    0.000393       0.000394
# 114  Zerox Exchange v2   263.149626  6.700862e+05    0.000393       0.000394
# 115  Zerox Exchange v2    56.872952  1.446193e+05    0.000393       0.000393
# 116  Zerox Exchange v2     7.066290  1.801407e+04    0.000392       0.000392
# 117  Zerox Exchange v2   484.210930  1.237816e+06    0.000391       0.000393
#
#      minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0         0.000443  1020252.0   45.000002  0.022707  2021-07-01 00:10:00
# 1         0.000445   728493.0   20.999999  0.015298  2021-07-01 00:40:00
# 2         0.000444   314499.0   26.150001  0.008224  2021-07-01 00:50:00
# 3         0.000447  2812987.0  157.999997  0.099707  2021-07-01 02:10:00
# 4         0.000453   563038.0   20.999999  0.011824  2021-07-01 03:00:00
# ..             ...        ...         ...       ...                  ...
# 113       0.000393  2893336.0  184.000004  0.157481  2021-07-31 22:50:00
# 114       0.000393  4809172.0  206.000001  0.167456  2021-07-31 23:10:00
# 115       0.000393  1409361.0   90.000001  0.041524  2021-07-31 23:20:00
# 116       0.000392   732690.0   68.000000  0.024809  2021-07-31 23:30:00
# 117       0.000391  3875196.0  134.999998  0.105897  2021-07-31 23:40:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 113                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 114                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 115                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 116                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 117                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 113                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 114                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 115                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 116                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 117                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [2438 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-06-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jun = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jun = jun.append(temp)
        #print(nov)


jun
# Out:
#              protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2     4.354977  1.182099e+04    0.000368       0.000368
# 1   Zerox Exchange v2    23.033874  6.286048e+04    0.000366       0.000367
# 2   Zerox Exchange v2    14.343939  3.903401e+04    0.000367       0.000368
# 3   Zerox Exchange v2    10.164468  2.774652e+04    0.000366       0.000367
# 4   Zerox Exchange v2    18.360208  5.000000e+04    0.000367       0.000367
# ..                ...          ...           ...         ...            ...
# 60  Zerox Exchange v2   737.313225  1.677590e+06    0.000440       0.000440
# 61  Zerox Exchange v2    31.000569  6.975000e+04    0.000444       0.000444
# 62  Zerox Exchange v2     0.065000  1.474438e+02    0.000441       0.000441
# 63  Zerox Exchange v2     8.498040  1.930063e+04    0.000440       0.000440
# 64  Zerox Exchange v2     0.310000  7.049094e+02    0.000440       0.000440
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000368   311705.0   27.000001  0.008416  2021-06-01 00:00:00
# 1        0.000366  1462399.0   87.000001  0.042207  2021-06-01 00:10:00
# 2        0.000367  1161985.0   54.000001  0.031374  2021-06-01 00:20:00
# 3        0.000365  1146437.0   79.000001  0.030742  2021-06-01 00:50:00
# 4        0.000367   258745.0   23.000001  0.005951  2021-06-01 01:00:00
# ..            ...        ...         ...       ...                  ...
# 60       0.000440  3462361.0  249.999999  0.865590  2021-06-30 21:30:00
# 61       0.000444   589970.0   35.000001  0.020649  2021-06-30 22:50:00
# 62       0.000441   296165.0   14.000000  0.004146  2021-06-30 23:10:00
# 63       0.000440   331731.0   19.666668  0.006524  2021-06-30 23:30:00
# 64       0.000440   296165.0   16.400000  0.004857  2021-06-30 23:40:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 60                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 61                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 62                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 63                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 64                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 60                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 61                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 62                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 63                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 64                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [2208 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-05-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        may = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        may = may.append(temp)
        #print(nov)


may
# Out:
#               protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0    Zerox Exchange v2     5.402553   14987.488200    0.000360       0.000360
# 1    Zerox Exchange v2    16.070726   44633.372252    0.000360       0.000361
# 2    Zerox Exchange v2     0.846676    2346.191354    0.000361       0.000361
# 3    Zerox Exchange v2    69.287033  191705.625067    0.000361       0.000362
# 4    Zerox Exchange v2     9.720000   26847.370800    0.000362       0.000362
# ..                 ...          ...            ...         ...            ...
# 104  Zerox Exchange v2    14.089410   37500.000000    0.000376       0.000376
# 105  Zerox Exchange v2    60.206742  159628.608805    0.000377       0.000378
# 106  Zerox Exchange v2     2.533995    6764.356699    0.000375       0.000375
# 107  Zerox Exchange v2    14.198722   38060.405771    0.000373       0.000373
# 108  Zerox Exchange v2     1.531934    4143.181200    0.000370       0.000370
#
#      minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0         0.000360   649690.0   46.000001  0.029886  2021-05-01 00:30:00
# 1         0.000360   747668.0   98.699997  0.037222  2021-05-01 00:40:00
# 2         0.000361   527216.0   35.999998  0.018980  2021-05-01 00:50:00
# 3         0.000361  1792723.0  141.999997  0.064290  2021-05-01 01:00:00
# 4         0.000362   427951.0   66.999998  0.014330  2021-05-01 01:20:00
# ..             ...        ...         ...       ...                  ...
# 104       0.000376   258769.0   33.999999  0.008798  2021-05-31 22:50:00
# 105       0.000377  1247353.0   60.999999  0.038933  2021-05-31 23:00:00
# 106       0.000375   321729.0   33.999999  0.010939  2021-05-31 23:10:00
# 107       0.000373   818609.0   31.000001  0.025377  2021-05-31 23:20:00
# 108       0.000370   243753.0   65.000002  0.015844  2021-05-31 23:50:00
#
#     baseCurrency.symbol                        baseCurrency.address  \
# 0                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                  USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                  ...                                         ...
# 104                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 105                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 106                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 107                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 108                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#     quoteCurrency.symbol                       quoteCurrency.address
# 0                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                   WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                   ...                                         ...
# 104                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 105                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 106                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 107                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 108                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [3040 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-04-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,31):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        apr = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        apr = apr.append(temp)
        #print(nov)


apr
# Out:
#              protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2    54.251203  105000.000000    0.000517       0.000517
# 1   Zerox Exchange v2    23.182697   44595.938795    0.000520       0.000520
# 2   Zerox Exchange v2   501.092844  971418.466182    0.000516       0.000518
# 3   Zerox Exchange v2   424.603939  817792.178077    0.000519       0.000519
# 4   Zerox Exchange v2    51.745696  100000.000000    0.000517       0.000517
# ..                ...          ...            ...         ...            ...
# 80  Zerox Exchange v2     3.000000    8250.630000    0.000364       0.000364
# 81  Zerox Exchange v2    13.962409   38483.551207    0.000363       0.000363
# 82  Zerox Exchange v2    22.670000   62442.935658    0.000363       0.000363
# 83  Zerox Exchange v2     1.550000    4295.069500    0.000361       0.000361
# 84  Zerox Exchange v2    78.967457  219753.799125    0.000359       0.000359
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000517   513938.0  262.000001  0.134652  2021-04-01 00:30:00
# 1        0.000520   350816.0  266.000007  0.093317  2021-04-01 01:30:00
# 2        0.000516  3931062.0  488.999993  0.887665  2021-04-01 01:40:00
# 3        0.000519  2101440.0  382.000005  0.401375  2021-04-01 02:30:00
# 4        0.000517   624904.0  185.000002  0.115607  2021-04-01 02:40:00
# ..            ...        ...         ...       ...                  ...
# 80       0.000364   237240.0   46.000001  0.010913  2021-04-30 22:40:00
# 81       0.000363   576125.0   38.999998  0.022469  2021-04-30 23:00:00
# 82       0.000362   916596.0  123.000001  0.061443  2021-04-30 23:20:00
# 83       0.000361   744131.0   84.999999  0.032570  2021-04-30 23:40:00
# 84       0.000359   215747.0   41.000002  0.008846  2021-04-30 23:50:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 80                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 81                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 82                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 83                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 84                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 80                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 81                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 82                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 83                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 84                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [1916 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-03-"""

part2 = """
    "}
    ) {

     
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        mar = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        mar = mar.append(temp)
        #print(nov)


mar
# Out:
#              protocol  quoteAmount     baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2   335.606836  480854.118420    0.000698       0.000698
# 1   Zerox Exchange v2    13.806243   20000.000000    0.000690       0.000690
# 2   Zerox Exchange v2    13.830780   20000.000000    0.000692       0.000692
# 3   Zerox Exchange v2     7.142417   10296.436562    0.000694       0.000694
# 4   Zerox Exchange v2     5.547196    8000.000000    0.000693       0.000693
# ..                ...          ...            ...         ...            ...
# 45  Zerox Exchange v2   453.712709  864279.490501    0.000525       0.000525
# 46  Zerox Exchange v2   460.643750  877825.762187    0.000525       0.000525
# 47  Zerox Exchange v2   107.334808  204342.707570    0.000525       0.000526
# 48  Zerox Exchange v2   416.577469  801548.251747    0.000520       0.000522
# 49  Zerox Exchange v2   101.211907  194231.722856    0.000521       0.000521
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000698  2475871.0   89.999999  0.222828  2021-03-01 00:10:00
# 1        0.000690   428732.0  103.999996  0.044588  2021-03-01 00:40:00
# 2        0.000692   418758.0  103.999996  0.043551  2021-03-01 01:00:00
# 3        0.000694   498242.0   95.000003  0.047333  2021-03-01 01:10:00
# 4        0.000693   250469.0   70.000001  0.017533  2021-03-01 01:30:00
# ..            ...        ...         ...       ...                  ...
# 45       0.000523  3843112.0  765.999989  0.789576  2021-03-31 22:40:00
# 46       0.000525  4103922.0  192.000000  0.787953  2021-03-31 22:50:00
# 47       0.000523  1106524.0  441.999999  0.235569  2021-03-31 23:00:00
# 48       0.000520  2051052.0  405.000012  0.414730  2021-03-31 23:40:00
# 49       0.000521  1056000.0  221.099999  0.233482  2021-03-31 23:50:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 45                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 46                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 47                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 48                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 49                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 45                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 46                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 47                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 48                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 49                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [2233 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-02-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,29):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        feb = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        feb = feb.append(temp)
        #print(nov)


feb
# Out:
#              protocol  quoteAmount    baseAmount  quotePrice  maximum_price  \
# 0   Zerox Exchange v2    40.577630  5.231681e+04    0.000776       0.000777
# 1   Zerox Exchange v2    20.000000  2.549560e+04    0.000784       0.000784
# 2   Zerox Exchange v2    33.193250  4.240297e+04    0.000783       0.000783
# 3   Zerox Exchange v2    76.068800  9.705162e+04    0.000784       0.000784
# 4   Zerox Exchange v2   179.518185  2.292713e+05    0.000783       0.000784
# ..                ...          ...           ...         ...            ...
# 82  Zerox Exchange v2     2.000000  2.834520e+03    0.000706       0.000706
# 83  Zerox Exchange v2   713.449161  1.011853e+06    0.000705       0.000706
# 84  Zerox Exchange v2   125.846144  1.819874e+05    0.000692       0.000692
# 85  Zerox Exchange v2    90.670945  1.306133e+05    0.000694       0.000694
# 86  Zerox Exchange v2   282.589935  4.019990e+05    0.000703       0.000705
#
#     minimum_price        gas    gasPrice  gasValue  timeInterval.minute  \
# 0        0.000770   617441.0  332.000002  0.098675  2021-02-01 00:00:00
# 1        0.000784   390684.0  299.999986  0.117205  2021-02-01 00:30:00
# 2        0.000782   922442.0  312.999993  0.137609  2021-02-01 00:40:00
# 3        0.000784  1063332.0  181.999993  0.193526  2021-02-01 00:50:00
# 4        0.000780  2385385.0  522.000007  0.308457  2021-02-01 01:00:00
# ..            ...        ...         ...       ...                  ...
# 82       0.000706   327440.0   93.999997  0.030779  2021-02-28 22:50:00
# 83       0.000696  2301064.0  389.000012  0.214986  2021-02-28 23:00:00
# 84       0.000692  1412562.0   92.999999  0.131368  2021-02-28 23:10:00
# 85       0.000694  1718434.0  192.399999  0.165313  2021-02-28 23:30:00
# 86       0.000703  2357340.0  153.999999  0.183046  2021-02-28 23:50:00
#
#    baseCurrency.symbol                        baseCurrency.address  \
# 0                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 1                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 2                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 3                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4                 USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..                 ...                                         ...
# 82                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 83                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 84                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 85                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 86                USDC  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
#    quoteCurrency.symbol                       quoteCurrency.address
# 0                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                  WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ..                  ...                                         ...
# 82                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 83                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 84                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 85                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 86                 WETH  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
# [2238 rows x 14 columns]

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2021-01-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        jan = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        jan = jan.append(temp)
        #print(nov)


jan

# %%
part1 = """
{
  ethereum {
    dexTrades(
    protocol: {is: "Zerox Exchange v2"}
    baseCurrency: {is: "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"} 
    quoteCurrency: {is: "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"}
    date: {is: "2020-12-"""

part2 = """
    "}
    ) {

      
      timeInterval {
        minute(count: 10)
      }
      protocol
      baseCurrency {
        symbol
        address
      }
      quoteCurrency {
        symbol
        address
      }
      quoteAmount
      baseAmount
      quotePrice
      maximum_price: quotePrice(calculate: maximum)
      minimum_price: quotePrice(calculate: minimum)
      gas
      gasPrice
      gasValue

    }
  }
}
"""


zero = "0"
for i in range(1,32):
    if i<10:
        query = part1 + zero + str(i) + part2
    else:
        query = part1 + str(i) + part2
    
    result = run_query(query)  # Execute the query
    
    if i==1:
        dec = pd.json_normalize(result['data']['ethereum']['dexTrades'])
    else:
        temp = pd.json_normalize(result['data']['ethereum']['dexTrades'])
        dec = dec.append(temp)
        #print(nov)


dec

# %%
total_dai_eth = nov
total_dai_eth = total_dai_eth.append(octo)
total_dai_eth = total_dai_eth.append(sep)
total_dai_eth = total_dai_eth.append(aug)
total_dai_eth = total_dai_eth.append(jul)
total_dai_eth = total_dai_eth.append(jun)
total_dai_eth = total_dai_eth.append(may)
total_dai_eth = total_dai_eth.append(apr)
total_dai_eth = total_dai_eth.append(mar)
total_dai_eth = total_dai_eth.append(feb)
total_dai_eth = total_dai_eth.append(jan)
total_dai_eth = total_dai_eth.append(dec)
total_dai_eth

# %%
total_dai_eth.to_csv(r'/Users/cameronwalcott/Dropbox/Mac/Desktop/Math 446/Final Data/Zeroxv2-USDC-WETH.csv', index = False)
